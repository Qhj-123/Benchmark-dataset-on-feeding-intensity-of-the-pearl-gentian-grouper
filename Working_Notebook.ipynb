# %% [markdown]
# <a href="https://colab.research.google.com/github/Qhj-123/Benchmark-dataset-on-feeding-intensity-of-the-pearl-gentian-grouper/blob/main/Working_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Use this google colab link to download the model

# %%
# !pip install -q gdown
# !gdown --fuzzy "https://drive.google.com/file/d/1RgMRWC32Jnyww4gVhKkphrJxlw2koTWl/view?usp=sharing" -O BD_model.pt



# !ls   # Check if the File is Downloaded


## If this link is not working, then you can directly download the model using "https://drive.google.com/file/d/1RgMRWC32Jnyww4gVhKkphrJxlw2koTWl/view?usp=sharing"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1RgMRWC32Jnyww4gVhKkphrJxlw2koTWl
# From (redirected): https://drive.google.com/uc?id=1RgMRWC32Jnyww4gVhKkphrJxlw2koTWl&confirm=t&uuid=c3cb4eee-74f4-4fc8-bec4-8f68656b0f52
# To: /content/yolov5/BD_model.pt
# 100% 94.6M/94.6M [00:01<00:00, 56.7MB/s]
# BD_model.pt	 data	     models	      requirements.txt	utils
# benchmarks.py	 detect.py   __pycache__      runs		val.py
# CITATION.cff	 export.py   pyproject.toml   segment
# classify	 hubconf.py  README.md	      train.py
# CONTRIBUTING.md  LICENSE     README.zh-CN.md  tutorial.ipynb

# %% [markdown]
# # Clone YOLOv5 and Set Up the Environment

# %%
# Clone the YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # Clone the YOLOv5 repo
# %cd yolov5

# Install YOLOv5 dependencies
# %pip install -qr requirements.txt  # Install required packages
# %pip install -q roboflow  # Install Roboflow for data management (if needed)

# Import required libraries
import torch
import os
from IPython.display import Image, clear_output  # To display images

# Verify setup
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17822, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 17822 (delta 16), reused 6 (delta 6), pack-reused 17794 (from 2)
# Receiving objects: 100% (17822/17822), 16.99 MiB | 19.30 MiB/s, done.
# Resolving deltas: 100% (12151/12151), done.
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 125.5 MB/s eta 0:00:00
# Setup complete. Using torch 2.10.0+cu128 (Tesla T4)

# %% [markdown]
# # Run Object Detection Using YOLOv5

# %%
# Run YOLOv5 object detection
# Generalize the model and image source paths
model_path = "/content/BD_model.pt"  # Replace with the path to your trained YOLOv5 model (e.g., 'BD_model.pt')
image_source = "/content/Images"  # Replace with the path to the folder or file containing images/videos


# Command for object detection
# !python detect.py --weights {model_path} --img 1280 --conf 0.4 --source {image_source} --save-txt  --hide-labels    # it will save the results in the runs/detect/exp/ directory. img 3328

# Explanation:
# --weights: Path to the trained YOLOv5 model file.
# --img: Image size for processing (e.g., 640, 1280,2560, etc. pixels).
# --conf: Confidence threshold for predictions (you can adjust).
# --source: Path to the image or video source.
# --save-txt: Save the detection results in text format.
# --hide-conf: Hide confidence scores in the output images.
# Out:
# detect: weights=['/content/best.pt'], source=/content/Images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=True, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-460-g3fb11111 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# image 1/5 /content/Images/R003849004_14.jpg: 352x1280 58 os, 50.3ms
# image 2/5 /content/Images/R003849004_15.jpg: 352x1280 52 os, 37.7ms
# image 3/5 /content/Images/R003851004_1014.jpg: 448x1280 50 os, 48.3ms
# image 4/5 /content/Images/R003851004_1015.jpg: 384x1280 23 os, 41.0ms
# image 5/5 /content/Images/v2.jpg: 928x1280 201 os, 85.8ms
# Speed: 0.8ms pre-process, 52.6ms inference, 16.6ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp3
# 5 labels saved to runs/detect/exp3/labels

# %% [markdown]
# # Summarize the Detection Results

# %%
# Specify the directory containing label files
dir = "runs/detect/exp/labels"  # Path to the folder with detection result labels

# Open a file to save the summary
summary_file = os.path.dirname(dir) + "/summary.txt"
with open(summary_file, "w") as summary:
    # Iterate through all label files in the directory
    for file in os.listdir(dir):
        # Count the number of lines (detections) in each label file
        num_lines = sum(1 for _ in open(dir + "/" + file))
        # Write the file name and number of detections to the summary
        summary.write(file + "\t" + str(num_lines) + "\n")

# Summary saved to the specified file
print(f"Summary of detections saved to: {summary_file}")
# Out:
# Summary of detections saved to: runs/detect/exp/summary.txt
